# %%
# %sql
SELECT id, COUNT(*) AS Conteggio
FROM workspace.pipeline_breweries.silver_breweries
GROUP BY id
HAVING COUNT(*) > 1

# %%
# %sql
SELECT *
FROM workspace.pipeline_breweries.gold_breweries
WHERE __END_AT IS NOT NULL

# %%
# %sql
SELECT *
FROM workspace.pipeline_breweries.silver_breweries
WHERE id = 'b4e012c5-0f36-4d0a-a40b-cbcb29c7ceed'

# %%
# %sql
SELECT *
FROM workspace.pipeline_breweries.gold_breweries
WHERE id = 'b4e012c5-0f36-4d0a-a40b-cbcb29c7ceed'
--__END_AT IS NOT NULL

# %%
# %sql
SELECT COUNT(*) 
FROM workspace.pipeline_breweries.gold_breweries
WHERE id = 'b4e012c5-0f36-4d0a-a40b-cbcb29c7ceed'
